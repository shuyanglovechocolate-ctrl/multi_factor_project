# %% [markdown]
# # Week 1 Factor Test
#
# Run `scripts/download_data.py`, `scripts/build_factor_panel.py`, and `scripts/week1_factor_test.py` before using this notebook.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
panel = pd.read_parquet(PROJECT_ROOT / 'data' / 'processed' / 'factor_panel.parquet')
panel.head()

# %%
ic_summary = pd.read_csv(PROJECT_ROOT / 'outputs' / 'week1' / 'factor_ic_summary.csv')
ic_summary

# %%
group_summary = pd.read_csv(PROJECT_ROOT / 'outputs' / 'week1' / 'group_return_summary.csv')
group_summary

# %%
from IPython.display import Image, display

figure_dir = PROJECT_ROOT / 'outputs' / 'week1' / 'figures'
for path in sorted(figure_dir.glob('ic_decay.png')):
    display(Image(filename=str(path)))
